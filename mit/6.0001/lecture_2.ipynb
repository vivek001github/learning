# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Hi = "hello world"
print(Hi)
# Out:
# hello world

# %%
Greetinig ="hi"  " "+ "vivek"
print(Greetinig)
# Out:
# hi vivek

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = 1
print(x)

x_str = str(x)
print("my fav number is", x, ".", "X+", )
print("my fav number is " + x_str + "." + "X+")
# Out:
# 1
# my fav number is 1 . X+
# my fav number is 1.X+

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n = input("You are in the lost forest: ")
while n.lower() == "right":
    n = input("You are in the lost forest.\n")  # Fixed the newline character
print("\nYou got out of the lost forest!\n")  # Fixed the newline characters and added missing backslashes
# Out:
# You got out of the lost forest!

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
